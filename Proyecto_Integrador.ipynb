# %% [markdown]
# # Entrega 3 Proyecto integrador
# #Maximiliano Ortiz Ron
# #A01732672
# #10/10/2021
# #link para google colab: https://colab.research.google.com/drive/17tDb_Zax4zzYNDB-ZgkIBvXGDtou7-yT?usp=sharing
# #link para github:
# > A finales de 2019 comenzó a esparcirse un virus denominado “Coronavirus” a lo largo de Asia, para mediados de 2020 prácticamente todos los países del mundo contaban con casos de dicho virus. Este virus es altamente contagioso y peligroso para personas con complicaciones de salud (como hipertensión, problemas respiratorios, cardiacos, etc.) Es por eso que se tiene que tener un arduo cuidado en ambientes laborales para minimizar los contagios y defunciones tanto como sea posible.
#
# > La primera solución lógica ante un caso como estos es implementar distanciamiento social entre la población en general y mantener este distanciamiento tanto como sea posible para disminuir los contagios, sin embargo, tener una cuarentena por tanto tiempo es un riesgo latente para la economía nacional e internacional (sin mencionar la economía personal de millones de personas), es por eso que se tiene que encontrar una alternativa lo suficientemente segura como para evitar contagios, pero lo suficientemente práctica como para no llevar a un estancamiento económico en la sociedad (el cuál se estima que tendrá represalias durante muchos años).
#
#
#
# > Se pueden implementar muchas alternativas y planes de trabajo ante esta contingencia, y muchos de estos planes son compatibles entre sí, por lo que en este programa se buscará hacer una base de datos que determine si una persona es o no apta para asistir a trabajar, basándose en sus características físicas, condiciones de salud, etc. De esta forma, se podrá seguir realizando actividades laborales de una forma normal y se protegerán a aquellas personas que pueden llegar encontrarse en riesgo al rodearse de mucha gente.
#
#
# > El programa se planea diseñar haciendo uso del programa Python y sus funciones ya que es una plataforma muy amigable y las funciones disponibles son muy útiles para trabajos como el de este tipo. Primero que nada se buscará hacer un menú que funcione a la par de un sistema de clases para que el usuario pueda elegir entre diferentes opciones que usar, estas opciones son:
#
#
# *   Alta de un empleado
# *   Calcular el IMC de un empleado
# *   Cambiar la información de un empleado
# *   Consultar la información de un empleado
# *   Reporte de todos los empleados
# *   Salir
#
#
# > Con un menú con estas opciones se puede llevar un control bastante completo de las características de cada empleado que se desee agregar, y de esta forma se pueden evitar contagios en personas consideradas población de riesgo.
#
# >Descripción de algoritmos: Cada algoritmo está descrito mediante comentarios dentro del archivo para una explicación más didáctica.
#
# >Plan de pruebas: Para probar que el programa esté bien programado se realizarán pruebas usando al menos dos veces cada función, agregando dos empleados inventados y corriendo el programa.
#
# >Reflexión: Durante la realización de este proyecto aprendí mucho a cerca de el uso y manejo de python, cosas como uso de herramientas o familiarización con el lenguaje. Al mismo tiempo aprendí mucho a cerca de el pensamiento computacional y el razonamiento lógico para la resolución de problemas.

# %%
todos = [] #esta es la matriz que guardará la información de los empleados, se usará en todas las funciones
empleados = "empleados.txt" #este es el archivo de texto que almacenará la información de los empleados para que se guarden los datos incluso si se cierra el programa
def menu(): #esta función despliega el menú de opciones 
  menu = ["Bienvenido al sistema de salud y bienestar de los empleados", "1- Alta de empleado","2- Calcular el imc de un empleado", "3- Cambiar la información de un empleado", "4- Consultar un empleado", "5- Reporte de todos los empleados", "6- Salir"]
  m = 0
  for m in range (len(menu)): #Se usa un for para escribir todas las líneas de la lista menú
    print (menu[m])

def alta_de_empleado(todos):
  #en esta función se hace uso de una lista para registrar toda la información de un usuario
  informacion = [] #Al principio se borra todo lo que está adentro de la lista para poder sobreescribirla cada que se vuelve a usar la función
  ID = int(input("Inserta el ID del empleado: "))
  informacion.append(ID)
  nom = str(input("Inserta el nombre del empleado: "))
  informacion.append(nom)
  edad = int(input("Inserta la edad del empleado: "))
  informacion.append(edad)
  w = float(input("Inserta el peso (en kg) del empleado: "))
  informacion.append(w)
  h = float(input("Inserta la altura (en m) del empleado: "))
  informacion.append(h) #Estas son las primeras preguntas
  while True:
    diabetes = int(input("¿El empleado sufre de diabetes? (1.SI, 2.NO): "))
    if diabetes == 1 or diabetes == 2:
      informacion.append(diabetes)
      break
    else:
      print("Respuesta inválida, vuelve a intentarlo por favor") 
  while True:
    hiper = int(input("¿El empleado sufre de hipertensión? (1.SI, 2.NO): "))
    if hiper == 1 or hiper == 2:
      informacion.append(hiper)
      break
    else:
      print("Respuesta inválida, vuelve a intentarlo por favor")
  while True:
    cora = int(input("¿El empleado sufre de complicaciones cardiacas? (1.SI, 2.NO): "))
    if cora == 1 or cora == 2:
      informacion.append(cora)
      break
    else:
      print("Respuesta inválida, vuelve a intentarlo por favor")
  while True:
    can = int(input("¿El empleado sufre de cancer? (1.SI, 2.NO): "))
    if can == 1 or can == 2:
      informacion.append(can)
      break
    else:
      print("Respuesta inválida, vuelve a intentarlo por favor")
  while True:
    tabaco = int(input("¿El empleado sufre de tabaquismo?  (1.SI, 2.NO): "))
    if tabaco == 1 or tabaco == 2:
      informacion.append(tabaco)
      break
    else:
      print("Respuesta inválida, vuelve a intentarlo por favor")
  while True:
    vac = int(input("¿El empleado ya está vacunado en contra del Covid-19? (1.SI, 2.NO): "))
    if vac == 1 or vac == 2:
      informacion.append(vac)
      break
    else: 
      print("Respuesta inválida, vuelve a intentarlo por favor") #en estas preguntas se usa un ciclo while para asegurar que el usuario solo ingrese las opciones disponibles, si no lo hace se repetirá la pregunta
  depto = int(input("Ingresa el número de departamento del empleado:"))
  informacion.append(depto)
  todos.append(informacion) #al final de la función se agrega la lista de información a la matriz general para que no se pierdan los datos del usuario
  print(informacion)
  return todos

def calc_imc(todos): #En esta función se calculará el IMC de todos los empleados y se desplegarán los porcentajes de salud
  t1 = "Clasificacion IMC"
  t2 = "IMC"
  t3 = "id"
  t4 = "Nombre"
  t5 = "Peso (en kg)"
  t6 = "Altura (en m)"
  ds = 0
  dm = 0
  da = 0
  n = 0
  s = 0
  print(f"{t1:<20} {t2:<20} {t3:<20} {t4:<20} {t5:<20} {t6:<20}")
  for empleado in todos: #Acá se calcula el IMC empleado por empleado 
    h = empleado[4]
    w = empleado[3]
    Imc = w/(h**2)
    IMC = round(Imc,2)
    clas = ""
    if IMC < 18.5:
      #Bajo peso
      if IMC < 16:
        #delgadez severa
        ds = ds+1
        clas = ("Delgadez severa")
      if IMC >= 16 and IMC < 17:
        #delgadez moderada
        dm = dm+1
        clas = ("Delgadez moderada")
      if IMC >= 17 and IMC < 18.5:
        #delgadez aceptable
        da = da+1
        clas = ("Delgadez aceptable")
    if IMC >= 18.5 and IMC < 25:
      #normal
      n = n+1
      clas = ("Normal")
    if IMC >= 25:
      #sobrepeso
      s = s+1
      clas = ("Sobrepeso")
    print(f"{clas:<20} {IMC:<20} {empleado[0]:<20} {empleado[1]:<20} {empleado[3]:<20} {empleado[4]:<20} ")
  print(f"Porcentajes:\nDelgadez severa: {(ds*100)/len(todos)}%\nDelgadez moderada: {(dm*100)/len(todos)}%\nDelgadez aceptable: {(da*100)/len(todos)}%\nNormal: {(n*100)/len(todos)}%\nSobrepeso: {(s*100)/len(todos)}% ")
  
  
def camb_info(todos): #En esta función se puede cambiar la información de el empleado que el usuario quiera 
  cond2 = 0
  cont = -1
  while True: #Se abre un ciclo while para asegurarse que el usuario ingrese una ID correcta
    emp = int(input("ingresa el ID del empleado que deseas modificar: "))
    for empleado in todos: #en este for se busca dentro de toda la matriz de empleados el empleado que tenga un ID que coincida con la que ingresa el usuario
      cont = cont+1
      if emp == empleado[0]:
        nueva = []
        nueva.append(empleado[0])
        nom = str(input(f"El nombre del empleado es {empleado[1]}, ¿A qué nombre deseas cambiarlo?: "))
        if nom != "":
          nueva.append(nom)
        else:
          nueva.append(empleado[1])
        edad = str(input(f"La edad del empleado es {empleado[2]}, ¿A qué valor deseas cambiarla?: "))
        if edad != "":
          nueva.append(int(edad))
        else:
          nueva.append(empleado[2])
        w = str(input(f"El peso del empleado es {empleado[3]}, ¿A qué valor deseas cambiarlo?: "))
        if w != "":
          nueva.append(int(w))
        else:
          nueva.append(empleado[3])
        h = str(input(f"La altura del empleado es {empleado[4]}, ¿A qué valor deseas cambiarla?: "))
        if h != "":
          nueva.append(float(h))
        else:
          nueva.append(empleado[4])
        diabetes = str(input("¿El empleado padece de daibetes? (1.SI, 2.NO): "))
        if diabetes != "":
          nueva.append(int(diabetes))
        else:
          nueva.append(empleado[5])
        hiper = str(input("¿El empleado padece de hipertensión? (1.SI, 2.NO): "))
        if hiper != "":
          nueva.append(int(hiper))
        else:
          nueva.append(empleado[6])
        cora = str(input("¿El empleado padece de problemas del corazón? (1.SI, 2.NO): "))
        if cora != "":
          nueva.append(int(cora))
        else:
          nueva.append(empleado[7])
        can = str(input("¿El empleado padece de cáncer? (1.SI, 2.NO): "))
        if can != "":
          nueva.append(int(can))
        else:
          nueva.append(empleado[8])
        tabaco = str(input("¿El empleado padece de tabaquismo? (1.SI, 2.NO): "))
        if tabaco != "":
          nueva.append(int(tabaco))
        else:
          nueva.append(empleado[9])
        vac = str(input("¿El empleado está vacunado? (1.SI, 2.NO): "))
        if vac != "":
          nueva.append(int(vac))
        else:
          nueva.append(empleado[10])
        depto = str(input("Ingresa el número de departamento del empleado: "))
        if depto != "":
          nueva.append(int(depto))
        else:
          nueva.append(empleado[11])
        cond3 = int(input(f"Nuevos datos:\n{nueva}\n¿Estás seguro de que quieres actalizar los datos del empleado?(1.SI, 2.NO) "))
        if cond3 == 1:
          todos[cont] = nueva #si el usuario desea que se cambie la información, la lista "nueva" reemplaza a la información original del empleado
        elif cond3 == 2:
          print("Ok, vuelva pronto") #si el usuario no quiere cambiar la información, la lista "nueva" no se usa
        cond2 = 1
    if cond2 == 0:
      print("No encontramos ese ID en nuestra base de datos, por favor vuelve a intentarlo\n")
    if cond2 == 1:
      break
  return todos

  

def cons_info(todos):#En esta función se permite que el usuario consulte los datos de un empleado en específico
  cond4 = 0
  while True: #Como en la función pasada, se usa un ciclo while para asegurarse que el usuario introduzca un ID válido
    emp = int(input("Ingresa el ID del empleado que deseas consultar: "))
    for empleado in todos: #Como en la función pasada, se usa un for para encontrar al empleado que coincida con el ID registrado
      if empleado[0] == emp:
        print(empleado)
        cond4 = 1
    if cond4 == 0:
      print("No encontramos este ID en nuestra base de datos, por favor vuelve a intentarlo")
    if cond4 == 1:
      break

def rep(todos): #En esta función el usuario puede ver un reporte de todos los empleados junto con sus porcentajes
  ID = "ID"
  nombre = "nombre"
  peso = "peso"
  altura = "altura"
  diabetes = "diabetes"
  hipertension = "hipertensión"
  corazon = "corazón"
  cancer = "cáncer"
  tabaquismo = "tabaquismo"
  vacunado = "vacunado"
  dc = 0
  hipc = 0
  cc = 0
  cancc = 0
  tabc = 0
  vacc = 0
  print(f"{ID:<15}{nombre:<15}{peso:<15}{altura:<15}{diabetes:<15}{hipertension:<15}{corazon:<15}{cancer:<15}{tabaquismo:<15}{vacunado:<15}")
  for persona in todos:
    if persona[4] == 1:
      d = "positivo"
      dc = dc+1
    else:
      d = "negativo"
    if persona[5] == 1:
      hip = "positivo"
      hipc = hipc+1
    else:
      hip = "negativo"
    if persona[6] == 1:
      c = "positivo"
      cc = cc+1
    else:
      c = "negativo"
    if persona[7] == 1:
      canc = "positivo"
      cancc = cancc+1
    else:
      canc = "negativo"
    if persona[8] == 1:
      tab = "positivo"
      tabc = tabc+1
    else:
      tab = "negativo"
    if persona[9] == 1:
      vac = "positivo"
      vacc = vacc+1
    else:
      vac = "negativo"
    print(f"{persona[0]:<15}{persona[1]:<15}{persona[2]:<15}{persona[3]:<15}{d:<15}{hip:<15}{c:<15}{canc:<15}{tab:<15}{vac:<15}")
  print(f"Porcentajes:\nDiabetes: {dc*100/len(todos)}%\nHipertensión: {hipc*100/len(todos)}%\nComplicaciones cardiacas: {cc*100/len(todos)}%\nCáncer: {cancc*100/len(todos)}%\nTabaquismo: {tabc*100/len(todos)}%\nVacunados: {vacc*100/len(todos)}%")

def leer(empleados): #En esta función se lee el archivo .txt que guarda la información de todos los empleados
  with open(empleados,"r") as empleados:
    lineas = empleados.readlines()
    for linea in lineas:
      linea = linea.replace("\n","") #Acá se reemplazan los saltos de renglón dentro del texto por espacios para que se guarden correctamente en la lista
      linea_chida = linea.split(",") 
      todos.append(linea_chida)

def escribir(empleados,todos): #En esta función se agrega información al archivo de información general de todos los empleados
  with open (empleados,"w") as empleados:
    for linea in todos:
      ind = 0
      for elemento in linea: #Este for se usa para cambiar todos los elementos de la lista a strings, para así poder agregarlos al archivo sin problemas
        nuevo = str(elemento)
        linea[ind] = nuevo
        ind = ind+1
      texto = ",".join(linea)
      empleados.write(texto + "\n")

def main():#Esta es la función principal, en la que se mandan a llamar al resto de funciones
  leer(empleados) #Primero se lee el archivo de empleados 
  menu() #Después se imprime el menú de opciones
  cond = 0
  while True: #Se abre un ciclo while para que la función main se repita las veces que el usuario lo desee
    op = int(input("\nIngresa el número de la opción que quieres usar: ")) #Se pide que el usuario inserte el número de función que quiere usar
    if op == 1: #Con los if se manda a llamar la función que el usuario quiera llamar
      alta_de_empleado(todos)
      cond = 1
    elif op == 2:
      if cond == 0:
        print("por favor ingresa la información de al menos un empleado para usar esta función")
      else:
        calc_imc(todos)
    elif op == 3:
      if cond == 0:
        print("por favor ingresa la información de al menos un empleado para usar esta función")
      else:
        camb_info(todos) 
    elif op == 4:
      if cond == 0:
        print("por favor ingresa la información de al menos un empleado para usar esta función")
      else:
        cons_info(todos)
    elif op == 5:
      if cond == 0:
        print("por favor ingresa la información de al menos un empleado para usar esta función")
      else:
        rep(todos)
    elif op == 6: #Si la opción es salir, se imprimen los créditos y se rompe el ciclo 
      print("Gracias por usar este programa")
      print("Hecho por:")
      print("Maximiliano Ortiz Ron A0173272")
      break
    else:
      print("Opción inválida, vuelve a intentarlo por favor")
    escribir(empleados,todos) #al final se usa la función de escribir para guardar los datos capturados en el archivo
main() #por último se manda a llamar a la función main para correr el programa
# Out:
# Bienvenido al sistema de salud y bienestar de los empleados
# 1- Alta de empleado
# 2- Calcular el imc de un empleado
# 3- Cambiar la información de un empleado
# 4- Consultar un empleado
# 5- Reporte de todos los empleados
# 6- Salir
#
# Ingresa el número de la opción que quieres usar: 6
# Gracias por usar este programa
# Hecho por:
# Maximiliano Ortiz Ron A0173272
